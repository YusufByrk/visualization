# %% [markdown]
# # 3.3 Datenvisualisierung Python
# ## Scatterplot, Barplot, Lineplot
# ### 26.04.2023
#
# * [dokumentation of Seaborn](https://seaborn.pydata.org/generated/seaborn.axes_style.html)
#
# * [cheat sheet](https://www.kaggle.com/code/themlphdstudent/cheat-sheet-seaborn-charts)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Heutiger Datensatz
df = sns.load_dataset("taxis")
df
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 0     2.15    0.0  12.95  yellow  credit card        Lenox Hill West
# 1     0.00    0.0   9.30  yellow         cash  Upper West Side South
# 2     2.36    0.0  14.16  yellow  credit card          Alphabet City
# 3     6.15    0.0  36.95  yellow  credit card              Hudson Sq
# 4     1.10    0.0  13.40  yellow  credit card           Midtown East
# ...    ...    ...    ...     ...          ...                    ...
# 6428  1.06    0.0   6.36   green  credit card      East Harlem North
# 6429  0.00    0.0  58.80   green  credit card                Jamaica
# 6430  0.00    0.0  17.30   green         cash    Crown Heights North
# 6431  0.00    0.0   6.80   green  credit card          East New York
# 6432  3.36    0.0  20.16   green  credit card            Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# 1                Upper West Side South      Manhattan       Manhattan
# 2                         West Village      Manhattan       Manhattan
# 3                       Yorkville West      Manhattan       Manhattan
# 4                       Yorkville West      Manhattan       Manhattan
# ...                                ...            ...             ...
# 6428              Central Harlem North      Manhattan       Manhattan
# 6429  East Concourse/Concourse Village         Queens           Bronx
# 6430                    Bushwick North       Brooklyn        Brooklyn
# 6431      East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432                   Windsor Terrace       Brooklyn        Brooklyn
#
# [6433 rows x 14 columns]

# %% [markdown]
# ## Scatterplot

# %%
#Einfacher Scatterplot
sns.scatterplot(data=df, x="distance", y="total")
# Out:
# <Axes: xlabel='distance', ylabel='total'>

# %%
#Einfacher Scatterplot mit Label, Titel, Ticks...
ax = sns.scatterplot(data=df, x="distance", y="total")
ax.set(xlabel="distance in miles", ylabel="total cost $")
ax.set(title="Scatterplot total cost vs. distance in miles")
ax.set_xticks([4,6,15,20,30,42])
ax.set_xlim([0,80])
plt.show()

# %%
sns.scatterplot(data=df, x="distance", y="total")
plt.title("Scatterplot total cost vs. distance in miles") # titel ı bu şekilde de verebiliriz yukarıdakine alternatif
# Out:
# Text(0.5, 1.0, 'Scatterplot total cost vs. distance in miles')

# %%
#Einfacher Scatterplot mit farbigem Gitter und farbiger Überschrift
with sns.axes_style(style="whitegrid", rc={"grid.color": "red", "text.color": "green", "xtick.top":True}):
    ax = sns.scatterplot(data=df, x="distance", y="total")
ax.set(xlabel="distance in miles", ylabel="total cost")
ax.set(title="Scatterplot total cost vs. distance in miles")
ax.set_xticks(range(0,40,2))
plt.show()

# %%
#Gruppierter Scatterplot
sns.scatterplot(data=df, x="distance", y="total", hue="payment")
# Out:
# <Axes: xlabel='distance', ylabel='total'>

# %%
#Gruppierter Scatterplot mit Style
sns.scatterplot(data=df, x="distance", y="total", hue="payment", style="payment") 
# style parametresi ile payment sütünunun elemanlarının görselde gösterilme şekli değişebiliyor
# Out:
# <Axes: xlabel='distance', ylabel='total'>

# %%
#Style und Hue mit kategorischen Infos
sns.scatterplot(data=df, x="distance", y="total", hue="payment", style="color")
# Out:
# <Axes: xlabel='distance', ylabel='total'>

# %%
#Numeric Hue
print(df["tip"].value_counts())
sns.scatterplot(data=df, x="distance", y="total", hue="tip")
# Out:
# tip
# 0.00    2311
# 1.00     312
# 2.00     211
# 2.16      89
# 1.86      79
#         ...
# 7.94       1
# 7.95       1
# 0.89       1
# 9.36       1
# 7.70       1
# Name: count, Length: 489, dtype: int64
# <Axes: xlabel='distance', ylabel='total'>

# %%
#Hue Farbe ändern
#Farbpaletten: https://seaborn.pydata.org/tutorial/color_palettes.html
print(df["tip"].value_counts())
sns.scatterplot(data=df, x="distance", y="total", hue="tip", palette="rocket")
# Out:
# tip
# 0.00    2311
# 1.00     312
# 2.00     211
# 2.16      89
# 1.86      79
#         ...
# 7.94       1
# 7.95       1
# 0.89       1
# 9.36       1
# 7.70       1
# Name: count, Length: 489, dtype: int64
# <Axes: xlabel='distance', ylabel='total'>

# %%
#Kategorische Farbpalette für sequentielle Daten
sns.scatterplot(data=df, x="distance", y="total", hue="tip", palette="deep")
# Out:
# <Axes: xlabel='distance', ylabel='total'>

# %%
#Marker selbst kontrollieren
#Liste an Markern: https://matplotlib.org/stable/api/markers_api.html
markers = {"yellow": "s", "green": "X"}
sns.scatterplot(data=df, x="distance", y="total", style="color", markers=markers)
# Out:
# <Axes: xlabel='distance', ylabel='total'>

# %%
#FacetGrid / auftrennen in mehrere Plots
sns.relplot(
    data=df, x="distance", y="total",
    col="color", hue="passengers", style="passengers",
    kind="scatter"
)

# %%
#Auch mit mehr als zwei Plots möglich
sns.relplot(
    data=df, x="distance", y="total",
    col="passengers", hue="tip",
    kind="scatter"
)

# %%
#Darstellung in Zeilen statt Spalten
sns.relplot(
    data=df, x="distance", y="total",
    row="color", hue="tip",
    kind="scatter"
)

# %%
#Darstellung in Zeilen UND Spalten
sns.relplot(
    data=df, x="distance", y="total",
    row="passengers", col="color", hue="tip",
    kind="scatter"
)

# %% [markdown]
# ## Übungsaufgabe Scatterplot

# %%
#Lade den penguins Datensatz und erstelle den im Unterricht gezeigten Scatterplot

# %% [markdown]
# ## Barplot

# %%
#Einfacher Barplot mit Konfidenzintervallen
sns.barplot(data=df, x="pickup_borough", y="total")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
#Einfacher Barplot mit anderen Fehlerbalken
sns.barplot(data=df, x="pickup_borough", y="total", errorbar="sd")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
#Gruppierter Barplot
sns.barplot(data=df, x="pickup_borough", y="total", hue="color")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
#Funktionsschau
sns.barplot(
    data=df, x="pickup_borough", y="total",
    errorbar="sd", capsize=.2, errcolor="green",
    linewidth=2, edgecolor="black"
)
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %% [markdown]
# ## Übungsaufgabe Barplot

# %%
#Lade den penguins Datensatz und erstelle den im Unterricht gezeigten Barplot

# %% [markdown]
# Für weitere Infos und Anpassungen:
# https://www.geeksforgeeks.org/adding-value-labels-on-a-matplotlib-bar-chart/

# %% [markdown]
# ## Lineplot

# %%
df = sns.load_dataset("flights")
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
#Einfacher Lineplot
sns.lineplot(data=df, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
#Gruppierter Lineplot
sns.lineplot(data=df, x="year", y="passengers", hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
#Gruppierter Lineplot mit Style
sns.lineplot(data=df, x="year", y="passengers", hue="month", style="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Mit Hue und Style getrennt wieder mehrere Variablen trennen
sns.lineplot(data=df, x="day", y="tip", hue="sex", style="smoker")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#Marker einsetzen
sns.lineplot(
    data=df,
    x="day", y="tip", hue="sex", style="sex",
    markers=True, dashes=False
)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#Errorbars als Marker (jetzt wird kombiniert)
sns.lineplot(
    data=df,
    x="day", y="tip", hue="sex", style="sex", err_style="bars", errorbar="sd",
    markers=True, dashes=False
)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## Übungsaufgabe Lineplot

# %%
#Lade den planets Datensatz und erstelle den im Unterricht gezeigten Lineplot
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
planet = sns.load_dataset("planets")

# %%
planet.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
grouped = planet.groupby('year').mean().reset_index()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3768\4118900090.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped = planet.groupby('year').mean().reset_index()

# %%
planet['category'] = planet['year'].apply(lambda x: 'before_2010' if x < 2010 else 'after_2010')

# %%
planet
# Out:
#                method  number  orbital_period   mass  distance  year  \
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
#          category
# 0     before_2010
# 1     before_2010
# 2      after_2010
# 3     before_2010
# 4     before_2010
# ...           ...
# 1030  before_2010
# 1031  before_2010
# 1032  before_2010
# 1033  before_2010
# 1034  before_2010
#
# [1035 rows x 7 columns]

# %%
planet.groupby("year").mean().index
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3768\1193078160.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   planet.groupby("year").mean().index
# Int64Index([1989, 1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#             2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#             2014],
#            dtype='int64', name='year')

# %%
sns.lineplot(data=df, x=planet.groupby("year").mean().index, y=planet.groupby("year").mean().distance, hue="category" )
plt.xlabel('Year')
plt.ylabel('Distance')
plt.title('Distance of Planets over Time')
plt.legend()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3768\300946779.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lineplot(data=df, x=planet.groupby("year").mean().index, y=planet.groupby("year").mean().distance, hue="category" )
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3768\300946779.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sns.lineplot(data=df, x=planet.groupby("year").mean().index, y=planet.groupby("year").mean().distance, hue="category" )
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 sns.lineplot(data=df, x=planet.groupby("year").mean().index, y=planet.groupby("year").mean().distance, hue="category" )
#       2 plt.xlabel('Year')
#       3 plt.ylabel('Distance')
#
# File c:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File c:\Users\Admin\anaconda3\lib\site-packages\seaborn\relational.py:692, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     677 @_deprecate_positional_args
#     678 def lineplot(
#     679     *,
#    (...)
#     688     legend="auto", ax=None, **kwargs
#     689 ):
#     691     variables = _LinePlotter.get_semantics(locals())
# --> 692     p = _LinePlotter(
#     693         data=data, variables=variables,
#     694         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#     695         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#     696     )
#     698     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     699     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File c:\Users\Admin\anaconda3\lib\site-packages\seaborn\relational.py:367, in _LinePlotter.__init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     353 def __init__(
#     354     self, *,
#     355     data=None, variables={},
#    (...)
#     361     # the kind of plot to draw, but for the time being we need to set
#     362     # this information so the SizeMapping can use it
#     363     self._default_size_range = (
#     364         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     365     )
# --> 367     super().__init__(data=data, variables=variables)
#     369     self.estimator = estimator
#     370     self.ci = ci
#
# File c:\Users\Admin\anaconda3\lib\site-packages\seaborn\_core.py:605, in VectorPlotter.__init__(self, data, variables)
#     603 def __init__(self, data=None, variables={}):
# --> 605     self.assign_variables(data, variables)
#     607     for var, cls in self._semantic_mappings.items():
#     608
#     609         # Create the mapping function
#     610         map_func = partial(cls.map, plotter=self)
#
# File c:\Users\Admin\anaconda3\lib\site-packages\seaborn\_core.py:668, in VectorPlotter.assign_variables(self, data, variables)
#     666 else:
#     667     self.input_format = "long"
# --> 668     plot_data, variables = self._assign_variables_longform(
#     669         data, **variables,
#     670     )
#     672 self.plot_data = plot_data
#     673 self.variables = variables
#
# File c:\Users\Admin\anaconda3\lib\site-packages\seaborn\_core.py:918, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     912         val_cls = val.__class__.__name__
#     913         err = (
#     914             f"Length of {val_cls} vectors must match length of `data`"
#     915             f" when both are used, but `data` has length {len(data)}"
#     916             f" and the vector passed to `{key}` has length {len(val)}."
#     917         )
# --> 918         raise ValueError(err)
#     920 plot_data[key] = val
#     922 # Try to infer the name of the variable
#
# ValueError: Length of Int64Index vectors must match length of `data` when both are used, but `data` has length 6433 and the vector passed to `x` has length 23.
